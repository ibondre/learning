# %%
## Setup
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
print(np.random.randint(1, 7))
# Out:
# 4

# %%
import numpy as np
print(np.random.randint(1, 7))
# Out:
# 1
